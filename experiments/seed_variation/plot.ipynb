# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
datadir = "data/rand_L=4_D=16_maxsv=10"

# %%
losses = np.load(os.path.join(datadir, "losses.npy"))
val_losses = np.load(os.path.join(datadir, "val_losses.npy"))
fidelities = np.load(os.path.join(datadir, "fidelities.npy"))
# bond_dims = np.load(os.path.join(datadir, "max_bond_dims.npy"))

# %%
numseed=len(losses)

# %%
fig, ax = plt.subplots()
for ii in range(numseed):
    plt.plot(fidelities[ii])

# %%
fig, ax = plt.subplots()
for ii in range(numseed):
    plt.plot(bond_dims[ii])

# %% [markdown]
# Note that the quality of training here is really independent of MPS seed.
